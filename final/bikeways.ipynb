# %%
import pandas as pd
import geopandas as gpd
import contextily as ctx
import plotly.express as px
import matplotlib.pyplot as plt

# %%
bikeways = gpd.read_file('LACity_Bikeways.zip')

# %%
bikeways.columns.to_list()
# Out:
# ['OBJECTID',
#  'Network',
#  'Bikeway',
#  'Street',
#  'From_',
#  'To_',
#  'Shape_Leng',
#  'Install_Da',
#  'Region',
#  'Bikeway_Ty',
#  'Datasource',
#  'geometry']

# %%
sub = ['Bikeway_Ty', 'geometry']

# %%
bikeways[sub]
# Out:
#                Bikeway_Ty                                           geometry
# 0                    Lane  LINESTRING Z (-118.23294 34.04017 0.00000, -11...
# 1                    Lane  LINESTRING Z (-118.23311 34.04119 0.00000, -11...
# 2                    Lane  LINESTRING Z (-118.23298 34.04045 0.00000, -11...
# 3                    Lane  LINESTRING Z (-118.23283 34.03920 0.00000, -11...
# 4     Protected Bike Lane  LINESTRING Z (-118.25847 33.79945 0.00000, -11...
# ...                   ...                                                ...
# 6370                 Lane  LINESTRING Z (-118.44435 34.15761 0.00000, -11...
# 6371                 Lane  LINESTRING Z (-118.44545 34.15761 0.00000, -11...
# 6372                 Lane  LINESTRING Z (-118.44654 34.15761 0.00000, -11...
# 6373                 Lane  LINESTRING Z (-118.44712 34.15761 0.00000, -11...
# 6374                 Lane  LINESTRING Z (-118.44763 34.15782 0.00000, -11...
#
# [6375 rows x 2 columns]

# %%
ax=bikeways[sub].plot(
            figsize=(20,12),   #size of the plot (a bit bigger than the default)
            column = 'Bikeway_Ty',   # column that defines the color of the dots
            legend = True,     # add a legend           
            legend_kwds={
               'loc': 'upper right',
               'bbox_to_anchor':(1,1)
            }                  # this puts the legend to the side
) 
ax.set_title("Bike Infrastructure, LA City (by type)")
ax.set_axis_off();
ctx.add_basemap(ax, crs='EPSG:4326', source=ctx.providers.CartoDB.Positron)

# %%
df.Bikeway_Ty.value_counts().sort_values().plot(kind = 'barh', title = '# of Bikeways, by type')
# Out:
# <AxesSubplot:title={'center':'# of Bikeways, by type'}>
