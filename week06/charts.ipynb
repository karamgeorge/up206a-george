# %%
import pandas as pd
import geopandas as gpd
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
crash = gpd.read_file('Ped_KSIs_by_CPA.zip')

# %%
type(crash)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
crash.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
crash.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 120 columns):
#  #    Column      Non-Null Count  Dtype
# ---   ------      --------------  -----
#  0    OBJECTID_1  37 non-null     int64
#  1    CPA_NUM     37 non-null     int64
#  2    NAME_ALF    37 non-null     object
#  3    CASE_ID     37 non-null     object
#  4    ACCIDENT_Y  37 non-null     int64
#  5    PROCDATE    37 non-null     int64
#  6    JURIS       37 non-null     int64
#  7    COLLISION_  37 non-null     int64
#  8    COLLISIO_1  37 non-null     int64
#  9    OFFICER_ID  37 non-null     object
#  10   REPORTING_  37 non-null     object
#  11   DAY_OF_WEE  37 non-null     object
#  12   SHIFT       37 non-null     object
#  13   POPULATION  37 non-null     object
#  14   CNTY_CITY_  37 non-null     object
#  15   SPECIAL_CO  37 non-null     object
#  16   BEAT_TYPE   37 non-null     object
#  17   CHP_BEAT_T  37 non-null     object
# ...

# %%
crash.head()
# Out:
#    OBJECTID_1  CPA_NUM                                           NAME_ALF  \
# 0           1     1070                                          Hollywood
# 1           2     2200  Canoga Park - Winnetka - Woodland Hills - West...
# 2           3     1110                                 Central City North
# 3           4     2210                          Chatsworth - Porter Ranch
# 4           5     3320                            Bel Air - Beverly Crest
#
#    CASE_ID  ACCIDENT_Y       PROCDATE  JURIS     COLLISION_  COLLISIO_1  \
# 0  4044110        2009  1251676800000   1942  1231804800000         830
# 1  4015242        2009  1243382400000   1942  1235001600000        1810
# 2  4245162        2009  1284681600000   1942  1238457600000        1320
# 3  4014901        2009  1284595200000   1942  1232582400000         820
# 4  5224254        2011  1349827200000   1942  1306886400000        2125
#
#   OFFICER_ID  ... City_ID Violation Violation_   IntID  SegID Crash_Coun  \
# ...

# %%
crash.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 120 columns):
#  #    Column      Non-Null Count  Dtype
# ---   ------      --------------  -----
#  0    OBJECTID_1  37 non-null     int64
#  1    CPA_NUM     37 non-null     int64
#  2    NAME_ALF    37 non-null     object
#  3    CASE_ID     37 non-null     object
#  4    ACCIDENT_Y  37 non-null     int64
#  5    PROCDATE    37 non-null     int64
#  6    JURIS       37 non-null     int64
#  7    COLLISION_  37 non-null     int64
#  8    COLLISIO_1  37 non-null     int64
#  9    OFFICER_ID  37 non-null     object
#  10   REPORTING_  37 non-null     object
#  11   DAY_OF_WEE  37 non-null     object
#  12   SHIFT       37 non-null     object
#  13   POPULATION  37 non-null     object
#  14   CNTY_CITY_  37 non-null     object
#  15   SPECIAL_CO  37 non-null     object
#  16   BEAT_TYPE   37 non-null     object
#  17   CHP_BEAT_T  37 non-null     object
# ...

# %%
crash['Crash_Coun'].plot()
# Out:
# <AxesSubplot:>

# %%
crash['Crash_Coun'].value_counts()
# Out:
# 27     4
# 28     2
# 50     2
# 167    1
# 67     1
# 52     1
# 227    1
# 71     1
# 45     1
# 12     1
# 286    1
# 75     1
# 263    1
# 56     1
# 49     1
# 74     1
# 47     1
# 17     1
# 85     1
# 53     1
# 40     1
# 44     1
# 154    1
# 32     1
# 95     1
# 39     1
# 1      1
# 94     1
# 23     1
# 7      1
# 24     1
# 11     1
# Name: Crash_Coun, dtype: int64

# %%
crash_count = crash[['NAME_ALF', 'Crash_Coun']]

# %%
crash_count.plot()
# Out:
# <AxesSubplot:>

# %%
crash_count.columns.to_list()
# Out:
# ['NAME_ALF', 'Crash_Coun']

# %%
crash_count.columns = ['CPA', 'Count']

# %%
crash_count.plot.bar(figsize=(10,10), x = 'CPA', y = 'Count', title='title')
# Out:
# <AxesSubplot:title={'center':'title'}, xlabel='CPA'>

# %%
crash_count_sorted= crash_count.sort_values('Count',ascending=False)

# %%
crash_count_sorted.plot.bar(figsize=(10,10), x = 'CPA', y = 'Count')
# Out:
# <AxesSubplot:xlabel='CPA'>

# %%
crash.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Columns: 120 entries, OBJECTID_1 to geometry
# dtypes: float64(6), geometry(1), int64(36), object(77)
# memory usage: 34.8+ KB
